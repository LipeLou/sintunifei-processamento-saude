# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/DADOS PARA A DIRF.xlsx', skiprows=2 ,index_col=0, sheet_name="MAR 2025")
mensalidades = pd.read_excel('/content/Relatorio_Demonstrativo_Repasse_Fatura-239025-091020250920.xls', index_col=0)

# %%
dados.head()
# Out:
#                     CARTEIRA DEPENDENCIA                              NOME  \
# CÓD DA FAMILIA
# 90.0            1.371384e+15     Titular          ADAILTON SANTOS OLIVEIRA
# 90.0            1.371384e+15      Esposa  APARECIDA RAIMUNDA DIAS OLIVEIRA
# 90.0            1.371384e+15       Filho         ANDRE AYRES DIAS OLIVEIRA
# NaN                      NaN         NaN                               NaN
# 251.0           1.371384e+15     Titular              ADAIR SALVADO JUNIOR
#
#                            CPF  NASCIMENTO  MENSALIDADE  CONSULTA  \
# CÓD DA FAMILIA
# 90.0            738.717.296-04  06/03/1969          NaN     239.8
# 90.0            004.080.536-07  15/09/1970          NaN     119.9
# 90.0            131.684.916-32  30/09/2002          NaN       NaN
# NaN                        NaN         NaN          NaN       NaN
# 251.0           430.541.966-15  13/01/1962          NaN       NaN
#
#                 RETROATIVO RN  RETROATIVO  TOTAL
# CÓD DA FAMILIA
# ...

# %%
mensalidades.head()
# Out:
#                                                                               Nome  \
# Código
# Código da Família: 90 - ADAILTON SANTOS OLIVEIRA                               NaN
# 1371384000090000                                          ADAILTON SANTOS OLIVEIRA
# 1371384000090019                                  APARECIDA RAIMUNDA DIAS OLIVEIRA
# 1371384000090140                                         ANDRE AYRES DIAS OLIVEIRA
# NaN                                                                            NaN
#
#                                                   Data Nasc.       Módulo  \
# Código
# Código da Família: 90 - ADAILTON SANTOS OLIVEIRA         NaN          NaN
# 1371384000090000                                  06/03/1969  701940998.0
# 1371384000090019                                  15/09/1970  701940998.0
# 1371384000090140                                  30/09/2002  701940998.0
# NaN                                                      NaN          NaN
#
# ...

# %%
nomes_dados = dados['NOME'].tolist()

for index, row in mensalidades.iterrows():
    nome_mensalidade = row['Nome']
    if nome_mensalidade not in nomes_dados:
        print(nome_mensalidade)
# Out:
# FERNANDA GUIMARAES PIO
# ANNA SOPHIA JARMILLA LEONARDO SVOBODA PANTAROTO
# JETER MIGUEL DOS SANTOS OLIVEIRA
